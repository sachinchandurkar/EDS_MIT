# %% [markdown]
# <a href="https://colab.research.google.com/github/sachinchandurkar/EDS_MIT/blob/main/Assignment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MatPlotLib

# %%
import matplotlib.pyplot as plt
x=[1,4,6,8,10,15]
y=[1,4,6,8,10,15]
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend("Graph-1")
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Parabola

# %%
import matplotlib.pyplot as plt
y1=[]
y2=[]
x=range(-100,100,10)
for i in x : y1.append(i**2)
for i in x : y2.append(i**2)
plt.plot(x,y1)
plt.plot(x,y2)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.ylim(-2000,2000)
plt.axhline(0)
plt.axvline(0)
plt.show()

# %% [markdown]
# # Sin(X) Graph

# %%
import numpy as np
x=np.arange(0,3*np.pi,0.1)
y1=np.sin(x)
plt.plot(x,y1,'yellow')
plt.show()

# %% [markdown]
# #Cos(x) Graph

# %%
import numpy as np
x=np.arange(0,3*np.pi,0.1)
y1=np.cos(x)
plt.plot(x,y1,'aqua')
plt.show()

# %% [markdown]
# # New Section

# %%
import matplotlib.pyplot as plt
x1=[]
x2=[]
y=range(-2000,2000,10)
for i in y : x1.append(i**2)
for i in y : x2.append(i**2)
plt.plot(x1,y)
plt.plot(x2,y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.ylim(-2000,2000)
plt.axhline(0)
plt.axvline(0)
plt.show()

# %% [markdown]
# #Bar Graph

# %%
import matplotlib.pyplot as plt
name=["A","B","C","D"]
value=[4,8,10,12]
c1=['aqua','g','b','brown']
plt.bar(name,value,color = c1)
plt.show()

# %% [markdown]
# # Line Graph

# %%
import matplotlib.pyplot as plt
# x axis values
x=[1,2,3,4,5,6]
# y axis values
y=[2,4,1,5,2,6]

#plotting the points
plt.plot(x, y, color='r', linestyle='dashed', linewidth=6, marker='*', markerfacecolor='black', markersize=12)

# setting x and y axis range
plt.ylim(1,8)
plt.xlim(1,8)

#naming the  x axis
plt.xlabel('x - axis')

#naming the  x axis
plt.ylabel('y - axis')

#giving a title to my graph
plt.title(' Customization!')

# function to show the plot
plt.show()

# %% [markdown]
# # Histogram

# %%
import matplotlib.pyplot as plt

# frequencies
ages=[2, 5, 70, 40, 30, 45, 50, 45, 43, 40, 44, 60, 7, 13, 57, 18, 90, 7, 32, 21, 20, 40]

#setting the ranges and no of intervals
range =(0,100)
bins = 10

#plotting a histogram
plt.hist(ages, bins, range, color='green', histtype='bar',rwidth=0.8)
#x-axis label
plt.xlabel('age')
#frequency label
plt.ylabel('no of people')
#plot title
plt.title('My histogram')

plt.show()

# %% [markdown]
# # New Section

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('vampir.csv')
print(df)


x =
# Out:
#         Name  Rollno  Attendance  Unnamed: 3  SGPA
# 0      Elena       1          80         NaN  9.00
# 1     Stefan       2          78         NaN  8.00
# 2      Damon       3          42         NaN  2.50
# 3   caroline       4          68         NaN  6.00
# 4     bonnie       5          91         NaN  5.00
# 5  Katherine       6          32         NaN  4.00
# 6     Jeremy       7          84         NaN  7.60
# 7       Matt       8          56         NaN  8.56
# 8       jack       9          75         NaN  4.70
# 9       Jena      10          78         NaN  6.70

# %% [markdown]
# # Slice

# %%
import matplotlib.pyplot as plt
slices = [3,7,8,9]
color = ['r','y','g','b']
plt.pie(slices, label = "activites" , color=  "colors" , startangle=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-303b64ffb26e> in <cell line: 4>()
#       2 slices = [3,7,8,9]
#       3 color = ['r','y','g','b']
# ----> 4 plt.pie(slices, label = "activites" , color=  "colors" , startangle=90)
#       5 plt.show()
#
# TypeError: pie() got an unexpected keyword argument 'label'

# %% [markdown]
# # Scatter Graph

# %%
x_values=[0,1,2,3,4,5]
y_values=[0,1,4,9,16,25]
plt.scatter(x_values, y_values, s=100, color='y')
plt.show()
