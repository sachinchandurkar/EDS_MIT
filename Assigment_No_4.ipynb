# %% [markdown]
# <a href="https://colab.research.google.com/github/sachinchandurkar/EDS_MIT/blob/main/Assigment_No_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
all_data=pd.read_csv("/content/1686715083343_all_data (1).csv")
all_data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0  176559.0  Bose SoundSport Headphones               1.0       99.99
# 1  176560.0                Google Phone               1.0      600.00
# 2  176560.0            Wired Headphones               1.0       11.99
# 3  176561.0            Wired Headphones               1.0       11.99
# 4  176562.0        USB-C Charging Cable               1.0       11.95
#
#          Order Date                        Purchase Address
# 0  04-07-2019 22:30       682 Chestnut St, Boston, MA 02215
# 1  04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001
# 2  04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001
# 3     05/30/19 9:27       333 8th St, Los Angeles, CA 90001
# 4    04/29/19 13:03  381 Wilson St, San Francisco, CA 94016

# %% [markdown]
# # **Clean up the data**

# %%
all_data.shape
# Out:
# (69, 6)

# %% [markdown]
# # **Drop raws on NAN**

# %%
#Find NAN
nan_df = all_data[all_data.isna().any(axis=1)]
display(nan_df.head())
all_data = all_data.dropna(how='all')
all_data.head()
# Out:
#     Order ID Product  Quantity Ordered  Price Each Order Date Purchase Address
# 36       NaN     NaN               NaN         NaN        NaN              NaN
# 51       NaN     NaN               NaN         NaN        NaN              NaN
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0  176559.0  Bose SoundSport Headphones               1.0       99.99
# 1  176560.0                Google Phone               1.0      600.00
# 2  176560.0            Wired Headphones               1.0       11.99
# 3  176561.0            Wired Headphones               1.0       11.99
# 4  176562.0        USB-C Charging Cable               1.0       11.95
#
#          Order Date                        Purchase Address
# 0  04-07-2019 22:30       682 Chestnut St, Boston, MA 02215
# 1  04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001
# 2  04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001
# 3     05/30/19 9:27       333 8th St, Los Angeles, CA 90001
# ...

# %% [markdown]
# ## **Get rid of text in order data column**

# %%
all_data = all_data[all_data['Order Date'].str[0:2]!='or']
print(all_data)
# Out:
#     Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176559.0  Bose SoundSport Headphones               1.0       99.99
# 1   176560.0                Google Phone               1.0      600.00
# 2   176560.0            Wired Headphones               1.0       11.99
# 3   176561.0            Wired Headphones               1.0       11.99
# 4   176562.0        USB-C Charging Cable               1.0       11.95
# ..       ...                         ...               ...         ...
# 64  259329.0    Lightning Charging Cable               1.0       14.95
# 65  259330.0       AA Batteries (4-pack)               2.0        3.84
# 66  259331.0    Apple Airpods Headphones               1.0      150.00
# 67  259332.0    Apple Airpods Headphones               1.0      150.00
# 68  259333.0  Bose SoundSport Headphones               1.0       99.99
#
#           Order Date                        Purchase Address
# ...

# %% [markdown]
# # **Make columns correct type**

# %%
all_data['quantity ordered'] = pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])

# %% [markdown]
# # Augment data with additional columns

# %% [markdown]
# ## Add month column

# %%
all_data['Month'] = all_data['Order Date'].str[0:2]
all_data['Month'] = all_data['Month'].astype('int32')
all_data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0  176559.0  Bose SoundSport Headphones               1.0       99.99
# 1  176560.0                Google Phone               1.0      600.00
# 2  176560.0            Wired Headphones               1.0       11.99
# 3  176561.0            Wired Headphones               1.0       11.99
# 4  176562.0        USB-C Charging Cable               1.0       11.95
#
#          Order Date                        Purchase Address  quantity ordered  \
# 0  04-07-2019 22:30       682 Chestnut St, Boston, MA 02215               1.0
# 1  04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001               1.0
# 2  04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001               1.0
# 3     05/30/19 9:27       333 8th St, Los Angeles, CA 90001               1.0
# 4    04/29/19 13:03  381 Wilson St, San Francisco, CA 94016               1.0
#
#    Month
# 0      4
# 1      4
# 2      4
# 3      5
# 4      4

# %% [markdown]
# ## **Add month column (alternative method)**

# %%
all_data['Month 2'] = pd.to_datetime(all_data['Order Date']).dt.month
all_data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0  176559.0  Bose SoundSport Headphones               1.0       99.99
# 1  176560.0                Google Phone               1.0      600.00
# 2  176560.0            Wired Headphones               1.0       11.99
# 3  176561.0            Wired Headphones               1.0       11.99
# 4  176562.0        USB-C Charging Cable               1.0       11.95
#
#          Order Date                        Purchase Address  quantity ordered  \
# 0  04-07-2019 22:30       682 Chestnut St, Boston, MA 02215               1.0
# 1  04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001               1.0
# 2  04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001               1.0
# 3     05/30/19 9:27       333 8th St, Los Angeles, CA 90001               1.0
# 4    04/29/19 13:03  381 Wilson St, San Francisco, CA 94016               1.0
#
#    Month  Month 2
# 0      4        4
# 1      4        4
# ...

# %% [markdown]
# # **Add city column**

# %%
def get_city(address):
  return address.split(",")[1].strip("")

def get_state(address):
   return address.split(",")[2].strip("")[1]

all_data['City'] = all_data['Purchase Address'].apply(lambda x: f"{get_city(x)} ({get_state(x)})")
all_data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0  176559.0  Bose SoundSport Headphones               1.0       99.99
# 1  176560.0                Google Phone               1.0      600.00
# 2  176560.0            Wired Headphones               1.0       11.99
# 3  176561.0            Wired Headphones               1.0       11.99
# 4  176562.0        USB-C Charging Cable               1.0       11.95
#
#          Order Date                        Purchase Address  quantity ordered  \
# 0  04-07-2019 22:30       682 Chestnut St, Boston, MA 02215               1.0
# 1  04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001               1.0
# 2  04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001               1.0
# 3     05/30/19 9:27       333 8th St, Los Angeles, CA 90001               1.0
# 4    04/29/19 13:03  381 Wilson St, San Francisco, CA 94016               1.0
#
#    Month  Month 2                City
# ...

# %% [markdown]
# # **Data Exploration**

# %% [markdown]
# Question 1: What was the best month for sales? How much was earned that month?

# %%
all_data['Sales'] = all_data['Quantity Ordered'].astype('int') * all_data['Price Each'].astype('float')

# %%
all_data.groupby(['Month']).sum()
# Out:
# <ipython-input-20-dce0a735c05d>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   all_data.groupby(['Month']).sum()
#         Order ID  Quantity Ordered  Price Each  quantity ordered  Month 2  \
# Month
# 4      7335546.0             123.0      885.80             123.0      160
# 5       353124.0               2.0      111.98               2.0       10
# 6       184076.0               1.0       14.95               1.0        6
# 8       726962.0               9.0       23.92               9.0       32
# 9      2378802.0              17.0      591.44              17.0       90
# 10      550924.0              11.0       10.67              11.0       30
# 11      740314.0              19.0       13.66              19.0       44
# ...

# %% [markdown]
# Question 2 : What city sold the most products ?

# %%
Dummycity=all_data.groupby(['City'])
print(Dummycity)
#city_max=all_data.groupby(['city]).sum()
#print(max(city_max))

# %% [markdown]
# Question 3 What product sold the most ? why doyou think it sold the most ?

# %%
product_group=all_data.groupby('Product')
quantity_ordered=product_group.sum()['Quantity Ordered']
# Out:
# <ipython-input-32-11142b314e0e>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   quantity_ordered=product_group.sum()['Quantity Ordered']

# %%
print(quantity_ordered)
# Out:
# Product
# AA Batteries (4-pack)          64.0
# AAA Batteries (4-pack)        109.0
# Apple Airpods Headphones        3.0
# Bose SoundSport Headphones      3.0
# Google Phone                    1.0
# Lightning Charging Cable        4.0
# USB-C Charging Cable            8.0
# Wired Headphones                7.0
# Name: Quantity Ordered, dtype: float64

# %%
prices=all_data.groupby('Product').mean()['Price Each']
# Out:
# <ipython-input-35-1f4f73bca841>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   prices=all_data.groupby('Product').mean()['Price Each']

# %%
print(prices)
# Out:
# Product
# AA Batteries (4-pack)           3.84
# AAA Batteries (4-pack)          2.99
# Apple Airpods Headphones      150.00
# Bose SoundSport Headphones     99.99
# Google Phone                  600.00
# Lightning Charging Cable       14.95
# USB-C Charging Cable           11.95
# Wired Headphones               11.99
# Name: Price Each, dtype: float64

# %% [markdown]
# Question 4 : What city sold the most products ?

# %%
df=all_data[all_data['Order ID'].duplicated(keep=False)]
df['Grouped']=df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df2=df[['Order ID','Grouped' ]].drop_duplicates()
print(df['Grouped'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fb6b60779b0b> in <cell line: 1>()
# ----> 1 df=all_data[all_data['Order ID'].duplicated(keep=False)]
#       2 df['Grouped']=df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#       3 df2=df[['Order ID','Grouped' ]].drop_duplicates()
#       4 print(df['Grouped'])
#
# NameError: name 'all_data' is not defined
